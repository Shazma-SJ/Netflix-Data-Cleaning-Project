# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("netflix_cleaned.csv")
count_type=df["Type"].value_counts()
print("Data counts: ",count_type)
# Out:
# Data counts:  Type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
###      Bar chart (Number of movies vs tv shows)

plt.figure(figsize=(6,5))

##       Pie Chart (proportion of movies vs tv shows)

count_type.plot(kind='pie', autopct='%1.1f%%')

plt.title('Proportion of Movies vs TV Shows', fontsize=14, fontweight='bold')
plt.ylabel('') # Hides the default 'Type' column label on the side
plt.show()

percentage=df["Type"].value_counts(normalize=True)*100
print("Percentages: ", percentage, "%")
# Out:
# Percentages:  Type
# Movie      69.692833
# TV Show    30.307167
# Name: proportion, dtype: float64 %

# %% [markdown]
# ## Task 2: Content Type Analysis — Summary
#
# | Analysis Step | Status | Remarks |
# |---|---|---|
# | Content Type Breakdown | ✅ | 69.7% Movies, 30.3% TV Shows |
# | Visualization | ✅ | Dashboard created with pie chart |
#
# ### Conclusion
#  "Movies dominate the netflix's content library, making upto 70% of Movies and 30% of TV Shows".
